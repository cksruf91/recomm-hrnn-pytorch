# %%
import argparse
import os
import pickle

import pandas as pd
import torch

from common.data_iterator import data_iterator
from config import CONFIG
from model.hrnn4recom import HRNN

# %%
pd.set_option("display.width", 150)

# %%
# class Argument:
#     user = 1422
#     dataset = '1M'
#     weight = 'hrnn_v1.0.1_e05-loss0.2407_nDCG0.436.zip'
#     eval_k = 10

class Argument:
    user = 3295 # 3293
    dataset = 'BRUNCH'
    weight = 'hrnn_v1.0.1_e12-loss0.1701_nDCG0.531.zip'
    eval_k = 10
    
def get_user_test_data(test_data, user_id):
    with open(test_data, 'r') as file:
        for line in file:
            line = [int(l) for l in line.split('\t')]
            if line[0] == user_id:
                return line[1], line[2:]
    raise ValueError(f'User {user_id} is not exist')

# %%
argument = Argument()
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
data_dir = os.path.join(CONFIG.DATA, argument.dataset)

# %%
# loading data
context_dataset = pickle.load(open(os.path.join(data_dir, f'valid.pkl'), 'rb'))
item_meta = pd.read_csv(os.path.join(data_dir, f'item_meta.tsv'), sep='\t', low_memory=False)
user_meta = pd.read_csv(os.path.join(data_dir, f'user_meta.tsv'), sep='\t', low_memory=False)
positive_item, negative_item = get_user_test_data(os.path.join(data_dir, 'negative_test.dat'), argument.user)
item_size = int(item_meta.item_id.max() + 1)

# %%
item_display_cols = ['item_id', 'Title', 'Genres']
user_display_cols = ['user_id', 'Gender', 'Age', 'Occupation', 'Zip-code']

if argument.dataset == 'BRUNCH':
    item_display_cols = ['item_id', 'author_id', 'title', 'display_url', 'keyword_list']
    user_display_cols = ['user_id','following_list']

# %%
# argument.user = 1422
user_contexts = context_dataset[argument.user]
user_meta[user_meta['user_id'] == argument.user]
# Out:
#       user_id keyword_list                                     following_list                                 id
# 5795     3295           []  ['@cardnews', '@sustainlife', '@langman', '@br...  #824cd5fcb359865da1a32b2f5d993869

# %%
item_meta.rename(columns={'user_id':'author_id'}, inplace=True)

# %%
history = pd.DataFrame(
    {'item_id': [int(c['outputItem']) for c in user_contexts],
     'rating': [int(c['rating']) for c in user_contexts],
     'Timestamp': [int(c['timestamp']) for c in user_contexts]}
)

# %%
# history.sort_values('timestamp', inplace=True)
history = history.merge(item_meta, on='item_id', how='left')
history[item_display_cols + ['rating', 'Timestamp'] ].tail(30)
# Out:
#     item_id        author_id                           title                              display_url              keyword_list  rating   Timestamp
# 0    192361       @seonju730                   어떤 뉴스를 좋아하세요?       https://brunch.co.kr/@seonju730/27       ['취향', '테스트', '뉴스']       5  1545901200
# 1    192362             @syn              06. 당신의 여행은 어떠십니까?             https://brunch.co.kr/@syn/27      ['여행', '스타일', '테스트']       5  1545901200
# 2    192363       @itisyoona  <코코> 보고 영어공부 시작한 썰 : 픽사 가고 싶어요       https://brunch.co.kr/@itisyoona/76     ['영어공부', '영어', '직장인']       5  1545901200
# 3    156979       @bitcommin                 멜론, 종자부터 브랜딩이다        https://brunch.co.kr/@bitcommin/42     ['농산물', '브랜딩', '브랜드']       5  1545901200
# 4    147571        @taekangk                   글로벌 기업의 회의 방법        https://brunch.co.kr/@taekangk/52       ['회의', '글로벌', '회사']       5  1547474400
# 5    180298         @roysday  소비자와 함께 만드는 참여형컨텐츠 10가지를 정리해보자        https://brunch.co.kr/@roysday/310    ['콘텐츠', '마케팅', '스타트업']       5  1547474400
# 6    178342          @dooook      넷플릭스가 영어공부에 가성비 갑인 세 가지 이유         https://brunch.co.kr/@dooook/142    ['영어공부', '미드', '넷플릭스']       5  1548266400
# 7    216674       @expediakr          특색 있는 전주 게스트하우스 BEST 5      https://brunch.co.kr/@expediakr/205            ['전주여행', '여행']       5  1548709200
# 8    216674       @expediakr          특색 있는 전주 게스트하우스 BEST 5      https://brunch.co.kr/@expediakr/205            ['전주여행', '여행']       5  1549918800
# 9    149400            @volo  동계 내일로 <전주 가볼 만한 곳 & 게스트하우스 추천           https://brunch.co.kr/@volo/413      ['전주', '여행', '전주여행']       5  1549918800
# 10   216674       @expediakr          특색 있는 전주 게스트하우스 BEST 5      https://brunch.co.kr/@expediakr/205            ['전주여행', '여행']       5  1549918800
# 11    35565  @hotelscombined        알쓸신잡 전주 숙소, 전주 게스트하우스 3곳  https://brunch.co.kr/@hotelscombined/79            ['전주숙소', '전주']       5  1549918800
# 12   216674       @expediakr          특색 있는 전주 게스트하우스 BEST 5      https://brunch.co.kr/@expediakr/205            ['전주여행', '여행']       5  1549918800
# 13   216675           @minon                전주의 한 게스트하우스 방문기           https://brunch.co.kr/@minon/47   ['친구', '게스트하우스', '매니저']       5  1549918800
# 14   216674       @expediakr          특색 있는 전주 게스트하우스 BEST 5      https://brunch.co.kr/@expediakr/205            ['전주여행', '여행']       5  1549918800
# 15   216676      @gnextstory    색다른 추억이 가득한 '전국 이색 게스트하우스 3'     https://brunch.co.kr/@gnextstory/250    ['여행', '게스트하우스', '휴가']       5  1549918800
# 16   225639      @mangoboard                    정돈된 것이 아름답다.       https://brunch.co.kr/@mangoboard/4      ['디자인', '콘텐츠', '광고']       5  1549918800
# 17   200852      @mangoboard         마케터들이여, 디자인 칼럼니스트가 되어라.       https://brunch.co.kr/@mangoboard/2     ['디자인', '마케팅', '마케터']       5  1550574000
# 18   212976         @roysday   책에선 도무지 알려주지 않는 리얼 민낯대화에 대한 썰        https://brunch.co.kr/@roysday/314   ['대화', '커뮤니케이션', '대화법']       5  1550574000
# 19   208622         @roysday        디자이너 눈에 비친 조금 다른 세상 20가지        https://brunch.co.kr/@roysday/313     ['디자인', '디자이너', '카페']       5  1550574000
# 20     3068     @intlovesong                  아끼면 똥 되는 것 4가지     https://brunch.co.kr/@intlovesong/28   ['칭찬', '인간관계', '소셜미디어']       5  1550574000
# 21   201938     @sparrowmill               재미있는 광고회사 면접.SSUL     https://brunch.co.kr/@sparrowmill/24       ['면접', '면접관', '재미']       5  1550574000
# 22   201890     @sparrowmill          Factbook 만들기 "어디서 찾지?"     https://brunch.co.kr/@sparrowmill/23   ['자료검색', '통계자료', '마케팅']       5  1550656800
# 23   201938     @sparrowmill               재미있는 광고회사 면접.SSUL     https://brunch.co.kr/@sparrowmill/24       ['면접', '면접관', '재미']       5  1550656800
# 24   174980     @sparrowmill            제안서 기초작업 Factbook만들기     https://brunch.co.kr/@sparrowmill/22    ['광고기획서', '마케팅', '제안']       5  1550656800
# 25   119221     @sparrowmill                광고회사AE 자기소개서 작성법     https://brunch.co.kr/@sparrowmill/13  ['직무경험', '자기소개서', '자소서']       5  1550656800
# 26   200122           @slist          [인터뷰] 설경구 "'살인자의 기억법'           https://brunch.co.kr/@slist/845      ['영화', '연기', '배우인생']       5  1550656800
# 27   220322       @getipower        트레바리는 왜 지금까지 투자를 받지 않았는가       https://brunch.co.kr/@getipower/74   ['투자', '벤처투자금', '스타트업']       5  1550667600
# 28   221128       @haesomsom     1. 인강과 학원의 나라, 대한민국 자원 이용하기        https://brunch.co.kr/@haesomsom/1       ['취업', '학원', '마케터']       5  1550678400
# 29   226013    @greenshifter                     버릴수록 행복한가요?     https://brunch.co.kr/@greenshifter/8  ['심플라이프', '사회', '미니멀리즘']       5  1550685600

# %%
# loading model
model_params = {
    'hiddenUnits': 100,  # 50
    'k': argument.eval_k, 'dropout': 0.2, 'item_size': item_size
}
hrnn = HRNN(
    model_params['hiddenUnits'], model_params['item_size'], device=device, k=model_params['k'],
    dropout=model_params['dropout']
)
weight = os.path.join('result', argument.dataset, argument.weight)
hrnn.load(weight)

# %%
# prediction
with torch.no_grad():
    recommend_items = hrnn.get_recommendation(
        data_iterator(user_contexts, device=device), argument.eval_k
    )

# %%
_, indices = torch.topk(recommend_items, argument.eval_k, dim=-1)

# %%
test_dataset = pd.DataFrame({'item_id': [positive_item]}) #  + negative_item
test_dataset = test_dataset.merge(item_meta, on='item_id', how='left', validate='1:m')
print(test_dataset.shape)
test_dataset[item_display_cols].head()
# Out:
# (1, 10)
#    item_id  author_id         title                        display_url           keyword_list
# 0    92664  @shindong  일 잘하는 사람의 특징  https://brunch.co.kr/@shindong/38  ['사람', '스타트업', '직장인']

# %%
recommend = pd.DataFrame({'item_id': indices.cpu().numpy()[0], 'user_id': argument.user})
recommend = recommend.merge(
    item_meta[item_display_cols], on='item_id', how='left', validate='1:m'
)
recommend = recommend.merge(
    user_meta[user_display_cols], on='user_id', how='left', validate='m:1'
)
print(recommend.shape)
recommend
# Out:
# (10, 7)
#    item_id  user_id       author_id                       title                             display_url               keyword_list  \
# 0   220899     3295             NaN                         NaN                                     NaN                        NaN
# 1   226013     3295   @greenshifter                 버릴수록 행복한가요?    https://brunch.co.kr/@greenshifter/8   ['심플라이프', '사회', '미니멀리즘']
# 2   227046     3295        @phillee  리암 니슨이 선보인 복수의 끝, 이번엔 다를까?         https://brunch.co.kr/@phillee/3             ['영화평점', '영화']
# 3   226007     3295     @hamsah0321        검사하면 정상인데, 나는 왜 아플까?      https://brunch.co.kr/@hamsah0321/1      ['검사', '질병', '아유르베다']
# 4   225494     3295         @icallu                       수영장에서        https://brunch.co.kr/@icallu/109   ['그림일기', '공감에세이', '드로잉']
# 5   230078     3295        @kidakhs    앙코르와트, 인간의 작품인가 신들의 작품인가        https://brunch.co.kr/@kidakhs/15  ['해외여행', '캄보디아', '앙코르와트']
# 6   228066     3295  @soul-music-ws         #11. 버스 맨 앞자리에 앉는 일  https://brunch.co.kr/@soul-music-ws/37         ['버스', '회사', '퇴근']
# 7   228021     3295      @yolo-life            '난임'이란 단어가 나에게..       https://brunch.co.kr/@yolo-life/6      ['난임', '임신', '자궁내막증']
# 8   220971     3295    @haleytravel                    몽골 여행의 꿈     https://brunch.co.kr/@haleytravel/4               ['몽골', '여행']
# 9   228002     3295     @wldud92221                      고삼 요거트     https://brunch.co.kr/@wldud92221/38   ['드로잉', '그림일기', '공감에세이']
#
#                                       following_list
# 0  ['@cardnews', '@sustainlife', '@langman', '@br...
# 1  ['@cardnews', '@sustainlife', '@langman', '@br...
# 2  ['@cardnews', '@sustainlife', '@langman', '@br...
# 3  ['@cardnews', '@sustainlife', '@langman', '@br...
# 4  ['@cardnews', '@sustainlife', '@langman', '@br...
# 5  ['@cardnews', '@sustainlife', '@langman', '@br...
# 6  ['@cardnews', '@sustainlife', '@langman', '@br...
# 7  ['@cardnews', '@sustainlife', '@langman', '@br...
# 8  ['@cardnews', '@sustainlife', '@langman', '@br...
# 9  ['@cardnews', '@sustainlife', '@langman', '@br...
